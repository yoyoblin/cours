# %% [markdown]
# # <span style="color:red">PROBA01 : Activité sur le hasard 01</span>

# %% [markdown]
# <h3 style="border:3px solid orange;">
#
# <span style="color:orange"> Vous allez utiliser, modifier et enfin créer des programmes qui vont simuler le lancer d'un dé à 6 faces.
#
# ![face%204.png](attachment:face%204.png)
#
# </h3>

# %% [markdown]
# ### <span style="color:orange"> 1. Simulation d'un seul lancer d'un dé à 6 faces :
# > - **Lancez plusieurs fois** le programme.
# > - **Remarque :** le **#** est utilisé pour ajouter des commentaires qui ne font pas partie du programme.
# > - **Comptez** le nombre d'apparition de chaque valeur et notez le sur votre feuille.

# %%
from random import*  # module de hasard

d = randint(1,6)     # tire au sort une valeur entière entre 1 et 6 --> affectation dans la variable d
print (d)            # affiche la variable d
# Out:
# 6

# %% [markdown]
# ___
# > - **Créez** un programme pour simuler le tirage au sort de deux dés : variables d1 et d2
# > - **Pour afficher** les deux variables on peut écrire `print(d1,d2)`

# %%
from random import*

# %% [markdown]
# ___
# ___
#
# ### <span style="color:orange"> 2. Simulation de plusieurs lancers successifs d'un dé :
# > **Vous allez utiliser une **boucle** qui répète 5 fois le lancer d'un dé à 6 faces**
# >> - **Modifiez** le programme  suivant pour faire 10 lancers, ou plus..
# >> - **Comptez** le nombre d'apparitions de chaque valeurs plusieurs fois de suite et notez le dans un tableau sur votre feuille.

# %%
from random import*  # module de hasard

for n in range(5) : # la boucle repète 5 fois les instructions indentées ci-après
    d = randint(1,6)     
    print (d)
# Out:
# 3
# 3
# 1
# 5
# 4

# %% [markdown]
# > - **Une valeur peut elle se répéter plusieurs fois ?**
