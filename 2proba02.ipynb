# %% [markdown]
# # <span style="color:red">PROBA02 : Activité sur le hasard 02</span>

# %% [markdown]
# <h3 style="border:3px solid orange;">
#
# <span style="color:orange"> Vous allez utiliser, modifier et enfin créer des programmes qui vont simuler le lancer d'une pièce de 1 euro... ou bien d'autres exemples...
#
# ![1-euro-fr.JPG](attachment:1-euro-fr.JPG)
#
# </h3>

# %% [markdown]
# ### <span style="color:orange"> 1. Simulation d'un seul lancer d'une pièce :
# > - **Lancez plusieurs fois** le programme.
# > - **Remarque :** le `#` est utilisé pour ajouter des commentaires qui ne font pas partie du programme.
# > - **Comptez** le nombre d'apparition de **pile** et notez le sur votre feuille.

# %%
from random import*

piece = ["pile", "face"]   # liste pour les issues possibles : ce sont des mots
r = choice(piece)          # tirage au sort dans la liste piece --> affectation à la variable f
print (r)                  # affiche la variable r (comme résultat)
# Out:
# pile

# %% [markdown]
# ___
# > - **Créez** un programme pour simuler le tirage au sort de deux pièces : variables r1 et r2
# > - **Pour afficher** les deux variables on peut écrire `print(r1,r2)`

# %%
from random import*

# %% [markdown]
# ___
#
# ### <span style="color:orange"> 2. Simulation de plusieurs lancers successifs d'une pièce :
# > - **Vous allez utiliser une **boucle** qui répète 10 fois le lancer d'une pièce de 1 euro**
# > - **Complétez et modifiez** le programme  suivant pour faire 10 lancers. Vous pouvez copier du code depuis les cellules précédentes.
# > - **Comptez** le nombre d'apparitions de 'pile" plusieurs fois de suite et notez le dans un tableau sur votre feuille.

# %%
from random import*  # module de hasard

for n in range(5) : # la boucle repète 5 fois les instructions indentées ci-après
# Out:
#   File "<input>", line 7
#
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3
# Error:

# %% [markdown]
# > - **Il ya t'il toujours autant de pile que de face ? Essayez pour 100 lancers**

# %% [markdown]
# ____
# ____
# ### <span style="color:orange"> 3. Autre exemple : la roue de la fortune...

# %% [markdown]
# <h3 style="border:3px solid orange;">
#
# <span style="color:orange"> Créez un programme pour simuler le tirage au sort entre quatre couleurs : vert, rouge, bleu.
#
# ![roue%20-%20Petite.jpeg](attachment:roue%20-%20Petite.jpeg)
#
# > - Utilisez des noms de variables et de liste adaptés à cette situation : par exemple "couleur" ou "roue"...
# > - Vous pouvez réutilisez du code précédent par copier coller
#
# </h3>

# %%
from random import*
